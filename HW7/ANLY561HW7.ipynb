# %% [markdown]
# ## ANLY561 Homework7
#
# ## Hongyang Zheng
#
#
# ### Question 1
#
# $$\nabla(g \circ f)(x)=\left\lgroup\begin{matrix}\frac{\partial(g \circ f)}{\partial f}\frac{\partial f}{\partial x_1}(x)\cr\frac{\partial(g \circ f)}{\partial f}\frac{\partial f}{\partial x_2}(x)\cr.\cr.\cr.\cr\frac{\partial(g \circ f)}{\partial f}\frac{\partial f}{\partial x_n}(x) \end{matrix}\right\rgroup$$
#
# $$=g'(f(x))\left\lgroup\begin{matrix}\frac{\partial f}{\partial x_1}(x)\cr\frac{\partial f}{\partial x_2}(x)\cr.\cr.\cr.\cr\frac{\partial f}{\partial x_n}(x) \end{matrix}\right\rgroup$$
#
# $$=g'(f(x))\nabla f(x)$$
#
#
# <br>
# ### Question 2
# #### a)
# $$\nabla f_1(x)^T=\left\lgroup\begin{matrix}\frac{\partial f_1}{\partial x_1}(x) & \frac{\partial f_1}{\partial x_2}(x) &...&\frac{\partial f_1}{\partial x_n}(x)\end{matrix}\right\rgroup$$
#
# $$\nabla f_2(x)^T=\left\lgroup\begin{matrix}\frac{\partial f_2}{\partial x_1}(x) & \frac{\partial f_2}{\partial x_2}(x) &...&\frac{\partial f_2}{\partial x_n}(x)\end{matrix}\right\rgroup$$
#
# $$.$$
# $$.$$
# $$.$$
#
#
# $$\nabla f_m(x)^T=\left\lgroup\begin{matrix}\frac{\partial f_m}{\partial x_1}(x) & \frac{\partial f_m}{\partial x_2}(x) &...&\frac{\partial f_m}{\partial x_n}(x)\end{matrix}\right\rgroup$$
#
# Therefore, we have:
# $$ Df(x)=\left\lgroup\begin{matrix}\nabla f_1(x)^T \cr \nabla f_2(x)^T \cr .\cr . \cr . \cr \nabla f_m(x)^T\end{matrix}\right\rgroup$$
#
# <br>
# #### b)
# $$\nabla(g \circ f)(x)=\left\lgroup\begin{matrix}\frac{\partial(g \circ f_1)}{\partial f_1}\frac{\partial f_1}{\partial x_1}(x)+\frac{\partial(g \circ f_2)}{\partial f_2}\frac{\partial f_2}{\partial x_1}(x)+...+\frac{\partial(g \circ f_m)}{\partial f_m}\frac{\partial f_m}{\partial x_1}(x)\cr\frac{\partial(g \circ f_1)}{\partial f_1}\frac{\partial f_1}{\partial x_2}(x)+\frac{\partial(g \circ f_2)}{\partial f_2}\frac{\partial f_2}{\partial x_2}(x)+...+\frac{\partial(g \circ f_m)}{\partial f_m}\frac{\partial f_m}{\partial x_2}(x)\cr.\cr.\cr.\cr\frac{\partial(g \circ f_1)}{\partial f_1}\frac{\partial f_1}{\partial x_n}(x)+\frac{\partial(g \circ f_2)}{\partial f_2}\frac{\partial f_2}{\partial x_n}(x)+...+\frac{\partial(g \circ f_m)}{\partial f_m}\frac{\partial f_m}{\partial x_n}(x) \end{matrix}\right\rgroup$$
#
# $$=\left\lgroup\begin{matrix}\frac{\partial f_1}{\partial x_1}(x)&\frac{\partial f_2}{\partial x_1}(x)&...&\frac{\partial f_m}{\partial x_1}(x)\cr\frac{\partial f_1}{\partial x_2}(x)&\frac{\partial f_2}{\partial x_2}(x)&...&\frac{\partial f_m}{\partial x_2}(x)\cr.&.&.\cr.&.& &.\cr.&.& & &.\cr\frac{\partial f_1}{\partial x_n}(x)&\frac{\partial f_2}{\partial x_n}(x)&...&\frac{\partial f_m}{\partial x_n}(x) \end{matrix}\right\rgroup\left\lgroup\begin{matrix}\frac{\partial(g \circ f_1)}{\partial f_1} \cr \frac{\partial(g \circ f_2)}{\partial f_2}\cr . \cr . \cr .\cr \frac{\partial(g \circ f_m)}{\partial f_m}\end{matrix}\right\rgroup$$
#
# $$=Df(x)^T \nabla g(f(x))$$
#
# <br>
# #### (c)
# Given $( g \circ f ) \in C^{1} ( R^{n}, R^{m})$ <br><br>
#
# $$D(g \circ f)({\bf x}) =
# \begin{pmatrix}
# \frac{\partial (g \circ f )_1}{\partial x_1}({\bf x})  & \frac{\partial (g \circ f )_1}{\partial x_2}({\bf x}) & ... &\frac{\partial (g \circ f )_1}{\partial x_n}({\bf x}) \\
# .\\.\\.\\
# \frac{\partial (g \circ f )_m}{\partial x_1}({\bf x})  & \frac{\partial (g \circ f )_m}{\partial x_2}({\bf x}) & ... &\frac{\partial (g \circ f )_m}{\partial x_n}({\bf x})
# \end{pmatrix}
# $$<br><br>
#
# $ g \in C^{1}( R^{k}, R^{m} ), f \in C^{1}( R^{n}, R^{k} )$ <br><br>
#
#
# $$D(g \circ f)({\bf x}) =
# \begin{pmatrix}
# \frac{\partial g_1}{\partial f_1} \frac{\partial f_1}{\partial x_1}({\bf x}) & \frac{\partial g_1}{\partial f_1} \frac{\partial f_1}{\partial x_2}({\bf x}) & ... & \frac{\partial g_1}{\partial f_1} \frac{\partial f_1}{\partial x_n}({\bf x}) \\
# .\\.\\.\\
# \frac{\partial g_m}{\partial f_k} \frac{\partial f_k}{\partial x_1}({\bf x}) & \frac{\partial g_m}{\partial f_k} \frac{\partial f_k}{\partial x_2}({\bf x}) & ... & \frac{\partial g_m}{\partial f_k} \frac{\partial f_k}{\partial x_n}({\bf x})
# \end{pmatrix}
# $$<br><br>
#
# Since
# $$Df({\bf x}) =
# \begin{pmatrix}
# \frac{\partial f_1}{\partial x_1}({\bf x}) & \frac{\partial f_1}{\partial x_2}({\bf x})& ... & \frac{\partial f_1}{\partial x_n}({\bf x}) \\
# .\\.\\.\\
# \frac{\partial f_m}{\partial x_1}({\bf x}) & \frac{\partial f_m}{\partial x_2}({\bf x}) & ... & \frac{\partial f_m}{\partial x_n}({\bf x})
# \end{pmatrix}
# $$ only values on diagonal line exist, like $\frac{\partial f_1}{\partial x_1},\frac{\partial f_2}{\partial x_2}...\frac{\partial f_m}{\partial x_n}$ exist, others are regarded as derivative on constants and will be $0$,<br><br>
#
# Therefore, we have
# $$Dg(f({\bf x})) =
# \begin{pmatrix}
# \frac{\partial g_1}{\partial f_1}({\bf x}) & ... & \frac{\partial g_1}{\partial f_k}({\bf x})\\
# \frac{\partial g_2}{\partial f_1}({\bf x}) & ... & \frac{\partial g_2}{\partial f_k}({\bf x})\\
# .\\.\\.\\
# \frac{\partial g_m}{\partial f_1}({\bf x}) & ... & \frac{\partial g_m}{\partial f_k}({\bf x})
# \end{pmatrix}
# $$ and
# $$Df({\bf x}) =
# \begin{pmatrix}
# \frac{\partial f_1}{\partial x_1}({\bf x}) & 0 & ... & 0 \\
# 0 & \frac{\partial f_2}{\partial x_2}({\bf x}) & ... & 0\\
# .\\.\\.\\
# 0 & 0 & ... & \frac{\partial f_m}{\partial x_n}({\bf x})
# \end{pmatrix}
# $$<br><br>
#
# Therefore,
# $D(g \circ f)({\bf x}) = Dg(f({\bf x}))Df({\bf x})$.

# %% [markdown]
# #### 3.
# #### (a)
# $$l(\widetilde{\beta}) = -\sum_{i=1}^{N}loglogit(y_i(\widetilde{\bf x}^{(i)})^{T}\widetilde{\beta}) = -\{ log logit(y_1 (\widetilde{\bf x}^{(1)})^{T}\widetilde{\beta} + ....log logit (y_n (\widetilde{\bf x}^{(n)})^{T}\widetilde{\beta}\} $$<br><br>
#
# $$=(1,1,1,...,1) \begin{pmatrix}
# -log logit(y_1 (\widetilde{\bf x}^{(1)})^{T}\widetilde{\beta}) \\
# -log logit(y_2 (\widetilde{\bf x}^{(2)})^{T}\widetilde{\beta}) \\
# .\\.\\.\\
# -log logit(y_n (\widetilde{\bf x}^{(n)})^{T}\widetilde{\beta})
# \end{pmatrix}
# $$<br><br>
#
# $$= s(
# \begin{pmatrix}
# -log logit(y_1 (\widetilde{\bf x}^{(1)})^{T}\widetilde{\beta}) \\
# -log logit(y_2 (\widetilde{\bf x}^{(2)})^{T}\widetilde{\beta}) \\
# .\\.\\.\\
# -log logit(y_n (\widetilde{\bf x}^{(n)})^{T}\widetilde{\beta})
# \end{pmatrix} )
# $$<br><br>
#
# $$ = s (
# \begin{pmatrix}
# -log logit(y_1 q_1) \\
# -log logit(y_2 q_2) \\
# .\\.\\.\\
# -log logit(y_n q_n)
# \end{pmatrix}),     q_i = (\widetilde{\bf x}^{(i)})^{T}\widetilde{\beta}
# $$<br><br>
#
# So $$l(\widetilde{\beta}) = s(g((\widetilde{\bf x}^{(i)})^{T}\widetilde{\beta}),$$<br><br>
# since $f(\widetilde{\beta}) = {\bf X}\widetilde{\beta}$ for $${\bf X} =
# \begin{pmatrix}
# (\widetilde{\bf x}^{(1)})^{T}\widetilde{\beta} \\
# (\widetilde{\bf x}^{(2)})^{T}\widetilde{\beta} \\
# .\\.\\.\\
# (\widetilde{\bf x}^{(n)})^{T}\widetilde{\beta}
# \end{pmatrix}
# $$<br><br>
#
# Therefore, $(\widetilde{\bf x}^{(i)})^{T}\widetilde{\beta} = f(\widetilde{\beta})$ and $l(\widetilde{\beta}) = s(g(f(\widetilde{\beta})))$<br><br><br>
#
# #### (b)
# We have $$\nabla l(\widetilde{\beta}) =
# \begin{pmatrix}
# \partial_1 ({{\bf 1}^{T}}_{N} g(f(\widetilde{\beta}))) \\
# \partial_2 ({{\bf 1}^{T}}_{N} g(f(\widetilde{\beta}))) \\
# .\\.\\.\\
# \partial_n ({{\bf 1}^{T}}_{N} g(f(\widetilde{\beta})))
# \end{pmatrix}
# $$<br><br>
#
# Using matrix product rule, $$\partial_n ({{\bf 1}^{T}}_{N} g(f(\widetilde{\beta}))) = \partial_n ( {{\bf 1}^{T}}_{N} )(g(f(\widetilde{\beta}))) + ( {{\bf 1}^{T}}_{N} ) \partial_n (g(f(\widetilde{\beta})))$$<br><br>
#
# ${{\bf 1}^{T}}_{N}$ is the vector with all entries all equal to 1, so $$\partial_n ({{\bf 1}^{T}}_{N} g(f(\widetilde{\beta})) = \partial_n (g(f(\widetilde{\beta})))$$<br><br>
#
# $$\partial_n g(f(\widetilde{\beta})) = \partial_n (-log logit (y_n X_n \widetilde{\beta}_n)) = - X_ny_nlogit(-y_nX_n\widetilde{\beta}_n) = X_nh(f(\widetilde{\beta}_n))$$<br><br>
#
# Therefore, $$\nabla l(\widetilde{\beta}) =
# \begin{pmatrix}
# X_1h(f(\widetilde{\beta}_1)) \\
# X_2h(f(\widetilde{\beta}_2)) \\
# .\\.\\.\\
# X_nh(f(\widetilde{\beta}_n))
# \end{pmatrix} = X^{T}h(f(\widetilde{\beta}))
# $$<br><br>
#
# #### (c)
# $$\nabla^{2} l(\widetilde{\beta}) =
# \begin{pmatrix}
# \partial_{1,1} X_1h(f(\widetilde{\beta}_1)) & \partial_{1,2} X_1h(f(\widetilde{\beta}_1)) & ...& \partial_{1,n} X_1h(f(\widetilde{\beta}_1))\\
# \partial_{1,2} X_2h(f(\widetilde{\beta}_2))& \partial_{2,2} X_2h(f(\widetilde{\beta}_2))  &... & \partial_{2,n} - X_2h(f(\widetilde{\beta}_2))\\
# .\\.\\.\\
# \partial_{1,n} X_nh(f(\widetilde{\beta}_n)) & \partial_{2,n} X_nh(f(\widetilde{\beta}_n)) & ... &\partial_{n,n} - X_nh(f(\widetilde{\beta}_n))
# \end{pmatrix}
# $$<br><br>
#
# The values on the diagonal line exist, others will be 0, pick one value:<br><br>
#
# $$\partial_n - X_ny_nlogit(-y_nX_n\widetilde{\beta}_n) = (-y_nX_n)- X_ny_nlogit(-(-y_nX_n\widetilde{\beta}_n))logit(-y_nX_n\widetilde{\beta}_n) = $$<br><br>
# $$X_n^{2}y_n^{2} logit(y_nX_n\widetilde{\beta}_n)logit(-y_nX_n\widetilde{\beta}_n)$$<br><br>
#
# Given $y_n$ equals either $1$ and $-1$, $$\partial_n - X_ny_nlogit(-y_nX_n\widetilde{\beta}_n) = X_nlogit(X_n\widetilde{\beta}_n)logit(-X_n\widetilde{\beta}_n)X_n$$<br><br>
#
# $\nabla^{2} l(\widetilde{\beta})=
# \begin{pmatrix}
# X_1logit(X_1\widetilde{\beta}_1)logit(-X_1\widetilde{\beta}_1)X_1 & ...& 0\\
# 0& X_2logit(X_2\widetilde{\beta}_2)logit(-X_2\widetilde{\beta}_2)X_2 &... \\
# .\\.\\.\\
# 0 & ... & X_nlogit(X_n\widetilde{\beta}_n)logit(-X_n\widetilde{\beta}_n)X_n
# \end{pmatrix} =
# $<br><br>
#
# $(X_1, X_2, ... , X_n)
# \begin{pmatrix}
# logit(X_1\widetilde{\beta}_1)logit(-X_1\widetilde{\beta}_1) & 0 & ... & 0 \\
# 0 & logit(X_2\widetilde{\beta}_2)logit(-X_2\widetilde{\beta}_2) & ... & 0 \\
# .\\.\\.\\
# 0 & 0 & ... &logit(X_n\widetilde{\beta}_n)logit(-X_n\widetilde{\beta}_n)
# \end{pmatrix}
# $
# $
# \begin{pmatrix}
# X_1 \\
# X_2 \\
# .\\.\\.\\
# X_n
# \end{pmatrix}
# $<br><br>
#
# Therefore, $\nabla^{2} l(\widetilde{\beta}) = X^{T}diag(G(f(\widetilde{\beta})))X$<br><br>
#
# #### (d)
# $\nabla^{2} l(\widetilde{\beta})^{T} = \nabla^{2} l(\widetilde{\beta})$, therefore $\nabla^{2} l(\widetilde{\beta})\in M_{n,n}$ is symmetric.<br><br>
#
# $G(f(\widetilde{\beta})) = logit(X\widetilde{\beta})logit(-X\widetilde{\beta}) \gt 0$ for all $\widetilde{\beta}$,$ diag(G(f(\widetilde{\beta}))) \gt 0$ for all $\widetilde{\beta}$<br><br>
#
# $\nabla^{2} l(\widetilde{\beta}) \geq 0$, and $z^{T}\nabla^{2} l(\widetilde{\beta})z \geq 0$ for all $z \in R^{n}$.<br><br>
#
# Therefore, $\nabla^{2} l(\widetilde{\beta})$ is always positive semidefinite.<br><br>
#
# #### (e)
# $\nabla^{2} l(\widetilde{\beta}) = X^{T}diag(G(f(\widetilde{\beta})))X$, by theorem "Eigenvalue Characterization of Positive Definiteness", $\nabla^{2} l(\widetilde{\beta})$ is positive definite if and only if it has strictly positive eigenvalues.<br><br>
#
# By spectral theorem, if $\nabla^{2} l(\widetilde{\beta})$ is in the form of $U^{T}diag(v)U$ where $U$ is orthogonal, then $v$ list the eigenvalues of $\nabla^{2} l(\widetilde{\beta})$.<br><br>
#
# $diag(G(f(\widetilde{\beta})))$ has strictly positive values in each entry, so if $X$ is orthogonal, the conditions are satisfied.<br><br>
#
# Therefore, $\nabla^{2} l(\widetilde{\beta})$ is positive definite when $X$ is orthogonal.<br><br>
#
# #### (f)
# Part (d) implies that $l(\widetilde{\beta})$ is convex.<br><br>
# Part (e) satisfied, then $l(\widetilde{\beta})$ is strictly convex.<br><br>
# When $\widetilde{\beta}^\ast$ satisfies $\nabla l(\widetilde{\beta}) = 0$ then it is the solution of $min_{\widetilde{\beta} \in R^{n}}l(\widetilde{\beta})$.
